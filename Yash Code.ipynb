# %% [markdown]
# # Yashaswini code

# %%
import datetime
import docx
import string,random
letno=''.join(random.sample(string.digits,1)+random.sample(string.ascii_letters,2))
from docx.shared import Pt
doc= docx.Document()
doc.add_heading('                            Letter',0)
today="-".join(str(i) for i in [datetime.date.today().day,  datetime.date.today().month, datetime.date.today().year])
typeleave = int(input("choose which category your reason falls:\n1 for sick leave\n2. attend events or ceremonies\n"))
if typeleave == 1:
    ndl=input("How many no.of days leave required(half/1/2...):\n")

    def hod(p):
        ndl=p
        name=input('Enter your name:\n').capitalize()
        cls=input("\nEnter branch-year section(example:cse-3a):\n").upper()
        rollno = input("ur rollno(Ex:19n31a0501):\n").upper()
        date=input('\nEnter date of leave in format dd-mm-yy:\n')
        to=input('\nTo whom Letter is written:\n').upper()
        Reason=input('\nEnter Reason(like fever/cough/leg fracture..):\n').capitalize()
        print( f'''
        To
        {to}
        {cls}
        MRCET

        Dear Sir/Madam;
        With due respect I want to inform that I {name} student of {cls}, rollno-{rollno} 
        have not been feeling well. As I am suffering from {Reason}, I will not be able 
        to attend classes for {ndl} day on {date}. So, please accept my request and 
        kindly grant me permission.
        I am hopeful that you accept my request and sanction me the leave.

        Thanking you,
        Yours Obediently,
        {name}


        signature
        {today}''')
        return f'''
        To
        {to}
        {cls}
        MRCET

        Dear Sir/Madam;
        With due respect I want to inform that I {name} student of {cls}, rollno-{rollno} 
        have not been feeling well. As I am suffering from {Reason}, I will not be able 
        to attend classes for {ndl} day on {date}. So, please accept my request and 
        kindly grant me permission.
        I am hopeful that you accept my request and sanction me the leave.

        Thanking you,
        Yours Obediently,
        {name}


        signature
        {today}'''



    def mod(p):
        ndl=p
        name=input('Enter your name:\n').capitalize()
        cls=input("\nEnter branch-year section(example:cse-3a):\n").upper()
        rollno = input("ur rollno(Ex:19n31a0501):\n").upper()
        sd=input('\nEnter date from when leave is required in format dd-mm-yy:\n')
        k=[int(i) for i in sd.split('-')]
        ed="-".join([str(k.pop(0)+int(ndl)-1)]+[str(i) for i in k])
        to=input('\nTo whom Letter is written:\n').upper()
        Reason=input('\nEnter Reason(fever/cough/hand fracture...):\n').capitalize()
        print( f'''
        TO
        {to}
        {cls}
        MRCET

        Dear sir/Madam;
        With due respect I want to inform that I {name} student of {cls}, rollno-{rollno} 
        have not been feeling well. As I am suffering from {Reason}, I will not be able to 
        attend classes for {ndl} days from {sd} to {ed}. So, please accept my request and 
        kindly grant me permission.
        I am hopeful that you accept my request and sanction me the leaves.

        Thanking you,
        Your Obediently,
        {name}
            
            
        signature
        {today}''')
        return f'''
        TO
        {to}
        {cls}
        MRCET

        Dear sir/Madam;
        With due respect I want to inform that I {name} student of {cls}, rollno-{rollno} 
        have not been feeling well. As I am suffering from {Reason}, I will not be able to 
        attend classes for {ndl} days from {sd} to {ed}. So, please accept my request and 
        kindly grant me permission.
        I am hopeful that you accept my request and sanction me the leaves.

        Thanking you,
        Your Obediently,
        {name}
            
            
        signature
        {today}'''




    if ndl=='half'or ndl=='1':
        m=hod(ndl)
    elif int(ndl) in [*range(2,61)]:
        m=mod(ndl)
    else:
        print("Plz Check inputs according to instructions and Enter again")
        
elif typeleave == 2:
    ndl=input("How many no.of days leave required(half/1/2...):\n")

    def hod(p):
        ndl=p
        name=input('Enter your name:\n').capitalize()
        cls=input("\nEnter branch-year section(example:cse-3a):\n").upper()
        rollno = input("ur rollno(Ex:19n31a0501):\n").upper()
        date=input('\nEnter date of leave in format dd-mm-yy:\n')
        to=input('\nTo whom Letter is written:\n').upper()
        Reason=input("\nur Reason(grandfather's death anniversary/sister's marriage):\n").capitalize()
        print( f'''
        To
        {to}
        {cls}
        MRCET

        Dear Sir/Madam;
        I am {name} student of {cls} having roll number {rollno}.I need to attend my 
        {Reason} on {date} for {ndl} day. So, I will not be able to attend the classes 
        for {ndl} day. Please accept my request and kindly grant me leave.\n
        I am hopeful that you accept my request and sanction me the leave. 


        Thanking you,
        Yours Obediently,
        {name}


        signature
        {today}''')
        return f'''
        To
        {to}
        {cls}
        MRCET

        Dear Sir/Madam;
        I am {name} student of {cls} having roll number {rollno}.I need to attend my 
        {Reason} on {date} for {ndl} day. So, I will not be able to attend the classes 
        for {ndl} day. Please accept my request and kindly grant me leave.\n
        I am hopeful that you accept my request and sanction me the leave. 


        Thanking you,
        Yours Obediently,
        {name}


        signature
        {today}'''



    def mod(p):
        ndl=p
        name=input('Enter your name:\n').capitalize()
        cls=input("\nEnter branch-year section(example:cse-3a):\n").upper()
        rollno = input("ur rollno(Ex:19n31a0501):\n").upper()
        sd=input('\nEnter date from when leave is required in format dd-mm-yy:\n')
        k=[int(i) for i in sd.split('-')]
        ed="-".join([str(k.pop(0)+int(ndl)-1)]+[str(i) for i in k])
        to=input('\nTo whom Letter is written:\n').upper()
        Reason=input("\nur Reason((grandfather's death anniversary/sister's marriage)):\n").capitalize()
        print( f'''
        TO
        {to}
        {cls}
        MRCET

        Dear sir/Madam;
        I am {name} student of {cls} having roll number {rollno}.I need to attend my 
        {Reason} from {sd} to {ed} for {ndl} days. So, I will not be able to attend 
        the classes for {ndl} days. Please accept this request and kindly grant me leave.\n
        I am hopeful that you accept my request and sanction me the leaves. 

        Thanking you,
        Your Obediently,
        {name}
             
            
        signature
        {today}''')
        return f'''
        TO
        {to}
        {cls}
        MRCET

        Dear sir/Madam;
        I am {name} student of {cls} having roll number {rollno}.I need to attend my 
        {Reason} from {sd} to {ed} for {ndl} days. So, I will not be able to attend 
        the classes for {ndl} days. Please accept this request and kindly grant me leave.\n
        I am hopeful that you accept my request and sanction me the leaves. 

        Thanking you,
        Your Obediently,
        {name}
             
            
        signature
        {today}'''



    if ndl=='half'or ndl=='1':
        m=hod(ndl)
    elif int(ndl) in [*range(2,61)]:
        m=mod(ndl)
    else:
        print("Plz Check inputs according to instructions and Enter again")
else:
    print("plz Check inputs according to instructions and Enter again -")
par = doc.add_paragraph().add_run(m)  
par.font.size=Pt(20)
doc.save(f'''C:\\Users\ASUS\Desktop\Letter{letno}.docx''')
print(f"\n\nLetter is saved in Desktop with file name of 'Letter{letno}'")
# Out:
# choose which category ur reason falls:
# 1 for sick leave
# 2. attend events or ceremonies
# 1
# How many no.of days leave required(half/1/2...):
# 1
# Enter your name:
# raja
#
# Enter branch-year section(example:cse-3a):
# mech-2b
# ur rollno(Ex:19n31a0501):
# 20n31a0537
#
# Enter date of leave in format dd-mm-yy:
# 20-10-2021
#
# To whom Letter is written:
# hod
#
# Enter Reason(like fever/cough/leg fracture..):
# stomach pain
#
#         To
#         HOD
#         MECH-2B
#         MRCET
#
#         Dear Sir/Madam;
#         With due respect I want to inform that I Raja student of MECH-2B, rollno-20N31A0537
#         have not been feeling well. As I am suffering from Stomach pain, I will not be able
#         to attend classes for 1 day on 20-10-2021. So, please accept my request and
#         kindly grant me permission.
#         I am hopeful that you accept my request and sanction me the leave.
#
#         Thanking you,
#         Yours Obediently,
#         Raja
#
#
# ...
